# %%
 if 'google.colab' in str(get_ipython()):
    # authorize & import/mount colab/google drive
    from google.colab import output
    from google.colab import drive
    from google.colab import auth
    drive.mount('/content/gd')

    # install libraries
    # !pip install --upgrade openai
    # !pip install --upgrade numba
    # !pip install transformers
    # !pip install sentence_transformers
    # !pip install unidecode
    # !pip install bertopic
    # !pip install unidecode
    # !pip install pandas==1.1.5

    # clear output
    output.clear()

# %%
import pandas as pd
import numpy as np
import re
import warnings
import openai
import json
pd.set_option('max_colwidth', 300)
warnings.filterwarnings("ignore")
import os

# %%
os.chdir("/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/Colab_notebooks/")

# %%
openai.api_key = os.environ['openai_api']

# %% [markdown]
# ## Classification

# %%
# Classification data is in memory
with open("classification_examples_w_labels.txt", "r") as fp:
  examples = json.load(fp)

# %%
len(examples)
# Out:
# 62

# %%
examples
# Out:
# [['Where did you grow up?', 'Factual'],
#  ["Is there a place you go when you go to inside of you when you're free soloing that's different then when you're out with ropes and bolts on a rock?",
#   'Non-factual'],
#  ['What is your name?', 'Factual'],
#  ['What do you want others to know or understand about you?', 'Non-factual'],
#  ['When and where were you born?', 'Factual'],
#  ['What are you most grateful for this year?', 'Non-factual'],
#  ['What are or were some of your hobbies?', 'Factual'],
#  ["If you're feeling down, how do you cheer yourself up?", 'Non-factual'],
#  ['Are you a sports fan? If so, what is your favorite team?', 'Factual'],
#  ['What is an interesting fact about you?', 'Factual'],
#  ['How do you handle anger and frustration?', 'Non-factual'],
#  ['What makes you feel most alive?', 'Non-factual'],
#  ['What is your usual breakfast?', 'Factual'],
#  ['Which language did your mom talk to you in?', 'Factual'],
#  ["Would you admit that most humans in pockets of society live within a status quo, that we live within the median, we don't take enough risks?",
#   'Non-factual'],
#  ['Where does confidence and self-belief come from?', 'Non-factual'],
#  ['Where did your dad get a permanent job?', 'Factual'],
#  ['Who is your sister?', 'Factual'],
#  ['Who is your wife?', 'Factual'],
#  ['When is your birthday?', 'Factual'],
#  ["Why don't you like to drink?", 'Non-factual'],
#  ['What is love?', 'Non-factual'],
#  ['What are your thoughts about fear during climbing?', 'Factual'],
#  ["Has your relationship with nature changed? I mean you've built a very close bond throughout your life with nature. Up close and personal, more than a lot of us so how would you define your relationship with nature in a way.",
#   'Non-factual'],
#  ['What do you believe is the most important characteristic your sons and daughters should have?',
#   'Non-factual'],
#  ['When and where did you attend college or university?', 'Factual'],
#  ['Do you have a favorite movie, song or book? What are they?', 'Factual'],
#  ['Why do you climb?', 'Non-factual'],
#  ['Who is your mom?', 'Factual'],
#  ["Don't you think it would benefit all of us to embrace the irrational a bit more or not to be so risk-averse in a way?",
#   'Non-factual'],
#  ['What is your favorite travel destination?', 'Factual'],
#  ['Is happiness just chemicals flowing through your brain or something more?',
#   'Non-factual'],
#  ['Can we really know everything?', 'Non-factual'],
#  ['What is consciousness?', 'Non-factual'],
#  ['Is there a meaning of life?', 'Non-factual'],
#  ['Do we have free will?', 'Non-factual'],
#  ['Where is your home town?', 'Factual'],
#  ['Do you have a medical condition?', 'Factual'],
#  ['How much money is in your bank account?', 'Factual'],
#  ['Given all of your experience, what would you do if someone tells you that you are not capable of doing something?',
#   'Non-factual'],
#  ['How much control do you have over your life?', 'Non-factual'],
#  ['Will racism cease to exist?', 'Non-factual'],
#  ['Tell me about a time that you failed.', 'Non-factual'],
#  ['When do you wake up in the morning?', 'Factual'],
#  ['How much does a Tesla cost?', 'Factual'],
#  ['Who is our president?', 'Factual'],
#  ['How did you learn how to climb?', 'Factual'],
#  ['When do you sleep?', 'Factual'],
#  ['What are your goals in life?', 'Non-factual'],
#  ['At what age did you start studying?', 'Factual'],
#  ['Why do you love climbing?', 'Non-factual'],
#  ['Why did you freesolo El Capitan in Yosemite?', 'Non-factual'],
#  ['What do you care about most?', 'Factual'],
#  ['What are your dreams?', 'Non-factual'],
#  ['What advice do you have for me?', 'Non-factual'],
#  ['If you could go back in time to change one thing, what would it be?',
#   'Non-factual'],
#  ['Is your glass half full or half empty?', 'Non-factual'],
#  ['How many languages do you speak?', 'Factual'],
#  ['Who was your favorite teacher in school and why?', 'Factual'],
#  ['What advice do you have for me?', 'Non-factual'],
#  ['What are some of your favorite adventures in life?', 'Non-factual'],
#  ['How are you?', 'Non-factual']]

# %%
# List out files we uploaded
openai.File.list()
# Out:
# <OpenAIObject list at 0x7fcdf0c6b4d0> JSON: {
#   "data": [
#     {
#       "bytes": 3563,
#       "created_at": 1632647535,
#       "filename": "compiled_results.csv",
#       "id": "file-CLHLESQvjr1UryRTmYscIfKU",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 63542,
#       "created_at": 1632611084,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Datasets/Alex_Honnold/gpt-3_prepared.jsonl",
#       "id": "file-VKluziYeJmZQFbnbj7j8fSD4",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 2376,
#       "created_at": 1632611201,
#       "filename": "compiled_results.csv",
#       "id": "file-yoyurg3ZcUpqmngIdJp7JGIv",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 264387,
#       "created_at": 1632647373,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Datasets/Alex_Honnold/gpt-3_prepared.jsonl",
#       "id": "file-CNua3CfLD8q3iriOVrSMZ1O0",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 52509,
#       "created_at": 1634779172,
#       "filename": "compiled_results.csv",
#       "id": "file-UrRYG69lxGJhfQDCUVyYis36",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 52443,
#       "created_at": 1634771601,
#       "filename": "compiled_results.csv",
#       "id": "file-8iRmGfyksuZ2BaRJrm5N0AR6",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 379118,
#       "created_at": 1634768541,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_prepared.jsonl",
#       "id": "file-4U0WzsIgRBnfiljAlgXGF9RD",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 379118,
#       "created_at": 1634772018,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_prepared.jsonl",
#       "id": "file-BBrh3Nz0MgyIgvGuqRjWjqJd",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 37107,
#       "created_at": 1633253136,
#       "filename": "compiled_results.csv",
#       "id": "file-EGfseVyEdbDStCj5ojJizfw8",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 277489,
#       "created_at": 1633252501,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_data_prepared.jsonl",
#       "id": "file-Rr2vrkYZgcLcqu26EdRa8Ao6",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 277489,
#       "created_at": 1633252446,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_data_prepared.jsonl",
#       "id": "file-5n3AQURZqg80yvLhkjOcfjNS",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 9214,
#       "created_at": 1633253703,
#       "filename": "compiled_results.csv",
#       "id": "file-kNFB81r6oGjKASZ9gaeRz7rq",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 1308639,
#       "created_at": 1633253340,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/erin_blog_1_prepared.jsonl",
#       "id": "file-ILwWyu3d0gFleO9p3fobxtId",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 60093,
#       "created_at": 1634803450,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/robert_clean_data_half_prepared.jsonl",
#       "id": "file-4bL4Z5eNNdbU4Kjyh4Kkzeni",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 5880,
#       "created_at": 1634803625,
#       "filename": "compiled_results.csv",
#       "id": "file-uxChM00Pks1FVpt4k1riqj8Z",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 391071,
#       "created_at": 1635232024,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_v2_prepared.jsonl",
#       "id": "file-0Ij1N2nGbl8fiAOUwgsr6TBa",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 391071,
#       "created_at": 1635232779,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_v2_prepared.jsonl",
#       "id": "file-jnmdfOdFUYvwliPUcHRzrFhm",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1635235291,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-9p0ZUGBnuqI8IEMgShzY4jVD",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 41517,
#       "created_at": 1635238610,
#       "filename": "compiled_results.csv",
#       "id": "file-WtC4sFxDpFMyLkuyjCkTPI7w",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 50893,
#       "created_at": 1635233737,
#       "filename": "compiled_results.csv",
#       "id": "file-NhT6MNxc76Z1wLFyqsayMiMw",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 11529,
#       "created_at": 1635232212,
#       "filename": "compiled_results.csv",
#       "id": "file-oQfRGwIY2sfJoINQk1KXD3om",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 391071,
#       "created_at": 1635232894,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_v2_prepared.jsonl",
#       "id": "file-DAmOoJwao3J77EdnS1Upy2g3",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 51245,
#       "created_at": 1635236128,
#       "filename": "compiled_results.csv",
#       "id": "file-9mARbSsX6oXF7msiH93VRzTn",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1635237805,
#       "filename": "/content/gd/MyDrive/w210_Capstone_Project_Fall2021/Repo/memorai/alice/raw_data/alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-tad5tqVjtYrTpswGqJSqmirN",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636945387,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-bGVN7xiKfJD2wwcym6R7NuT0",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 40761,
#       "created_at": 1636946796,
#       "filename": "compiled_results.csv",
#       "id": "file-qj62DS7CdimMFuLHwiD8fvKd",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636943264,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-rpmVa0AVr4iqVR1BKIlvocN8",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636939532,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-w709eQO18n9baS1LDw7gwybc",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 14750,
#       "created_at": 1636944020,
#       "filename": "compiled_results.csv",
#       "id": "file-oCBo2LRRk57XmfIbFj2hCBa5",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 1647,
#       "created_at": 1636940419,
#       "filename": "compiled_results.csv",
#       "id": "file-j6Ay57lwBuc4dlj6J6m2zSXZ",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636944348,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-kQfwdIzhWiUdahZy831Prypz",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636939009,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-RWFW6ZWa5gp9G7uESeiBQqtu",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636939513,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-K3t85yqMb6FwGYU7Pjpd07rO",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636942360,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-3jp6cj4VkzHWOJ3VUuTGnXCI",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 1656,
#       "created_at": 1636943222,
#       "filename": "compiled_results.csv",
#       "id": "file-YtYmSBjOqrui0Zgvo2RKuWqt",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 14647,
#       "created_at": 1636945104,
#       "filename": "compiled_results.csv",
#       "id": "file-2I7rkb9M5BNKCbI8KgCm61RX",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636946897,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-1hvVXu20HpLCIbqgjNv0Ugup",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 4288,
#       "created_at": 1636947696,
#       "filename": "compiled_results.csv",
#       "id": "file-85JVSJvwFavTLmtLgyNxIxao",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 395337,
#       "created_at": 1636967204,
#       "filename": "alex_combined_data_full_v3_prepared.jsonl",
#       "id": "file-ISUVwuo6icUXhMqCXRH2LY4Z",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 4310,
#       "created_at": 1636968003,
#       "filename": "compiled_results.csv",
#       "id": "file-wuKOhx70lmcmWvI013mWZNDz",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 378273,
#       "created_at": 1637611753,
#       "filename": "questionanswer.jsonl",
#       "id": "file-BDH9LO6abwU0x3Gn55Q2Gjhk",
#       "object": "file",
#       "purpose": "answers",
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "bytes": 378225,
#       "created_at": 1637812059,
#       "filename": "questionanswer.jsonl",
#       "id": "file-mcgwAkzglsZSibNyeFuuGjcH",
#       "object": "file",
#       "purpose": "answers",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "object": "list"
# }

# %%
# Test out Classification endpoint
openai.Classification.create(
    search_model="ada", 
    model="davinci",
    examples= examples,
    query="When is love going to come?",
    labels = ["Factual","Non-factual"], 
    temperature=0,   
    max_examples=len(examples)
)
# Out:
# <OpenAIObject classification at 0x7f5675b9b170> JSON: {
#   "completion": "cmpl-4BCxze4lQSIKjOutbbZOg5aW5Cq0I",
#   "label": "Non-factual",
#   "model": "davinci:2020-05-03",
#   "object": "classification",
#   "search_model": "ada",
#   "selected_examples": [
#     {
#       "document": 4,
#       "label": "Factual",
#       "text": "When and where were you born?"
#     },
#     {
#       "document": 0,
#       "label": "Factual",
#       "text": "Where did you grow up?"
#     },
#     {
#       "document": 1,
#       "label": "Non-factual",
#       "text": "Is there a place you go when you go to inside of you when you're free soloing that's different then when you're out with ropes and bolts on a rock?"
#     },
#     {
#       "document": 24,
#       "label": "Non-factual",
#       "text": "What do you believe is the most important characteristic your sons and daughters should have?"
#     },
#     {
#       "document": 56,
#       "label": "Non-factual",
#       "text": "Is your glass half full or half empty?"
#     },
#     {
#       "document": 42,
#       "label": "Non-factual",
#       "text": "Tell me about a time that you failed."
#     },
#     {
#       "document": 10,
#       "label": "Non-factual",
#       "text": "How do you handle anger and frustration?"
#     },
#     {
#       "document": 34,
#       "label": "Non-factual",
#       "text": "Is there a meaning of life?"
#     },
#     {
#       "document": 32,
#       "label": "Non-factual",
#       "text": "Can we really know everything?"
#     },
#     {
#       "document": 25,
#       "label": "Factual",
#       "text": "When and where did you attend college or university?"
#     },
#     {
#       "document": 54,
#       "label": "Non-factual",
#       "text": "What advice do you have for me?"
#     },
#     {
#       "document": 26,
#       "label": "Factual",
#       "text": "Do you have a favorite movie, song or book? What are they?"
#     },
#     {
#       "document": 35,
#       "label": "Non-factual",
#       "text": "Do we have free will?"
#     },
#     {
#       "document": 31,
#       "label": "Non-factual",
#       "text": "Is happiness just chemicals flowing through your brain or something more?"
#     },
#     {
#       "document": 23,
#       "label": "Non-factual",
#       "text": "Has your relationship with nature changed? I mean you've built a very close bond throughout your life with nature. Up close and personal, more than a lot of us so how would you define your relationship with nature in a way."
#     },
#     {
#       "document": 61,
#       "label": "Non-factual",
#       "text": "How are you?"
#     },
#     {
#       "document": 48,
#       "label": "Non-factual",
#       "text": "What are your goals in life?"
#     },
#     {
#       "document": 20,
#       "label": "Non-factual",
#       "text": "Why don't you like to drink?"
#     },
#     {
#       "document": 17,
#       "label": "Factual",
#       "text": "Who is your sister?"
#     },
#     {
#       "document": 19,
#       "label": "Factual",
#       "text": "When is your birthday?"
#     },
#     {
#       "document": 47,
#       "label": "Factual",
#       "text": "When do you sleep?"
#     },
#     {
#       "document": 60,
#       "label": "Non-factual",
#       "text": "What are some of your favorite adventures in life?"
#     },
#     {
#       "document": 15,
#       "label": "Non-factual",
#       "text": "Where does confidence and self-belief come from?"
#     },
#     {
#       "document": 39,
#       "label": "Non-factual",
#       "text": "Given all of your experience, what would you do if someone tells you that you are not capable of doing something?"
#     },
#     {
#       "document": 37,
#       "label": "Factual",
#       "text": "Do you have a medical condition?"
#     },
#     {
#       "document": 21,
#       "label": "Non-factual",
#       "text": "What is love?"
#     },
#     {
#       "document": 45,
#       "label": "Factual",
#       "text": "Who is our president?"
#     },
#     {
#       "document": 2,
#       "label": "Factual",
#       "text": "What is your name?"
#     },
#     {
#       "document": 16,
#       "label": "Factual",
#       "text": "Where did your dad get a permanent job?"
#     },
#     {
#       "document": 13,
#       "label": "Factual",
#       "text": "Which language did your mom talk to you in?"
#     },
#     {
#       "document": 40,
#       "label": "Non-factual",
#       "text": "How much control do you have over your life?"
#     },
#     {
#       "document": 30,
#       "label": "Factual",
#       "text": "What is your favorite travel destination?"
#     },
#     {
#       "document": 41,
#       "label": "Non-factual",
#       "text": "Will racism cease to exist?"
#     },
#     {
#       "document": 59,
#       "label": "Non-factual",
#       "text": "What advice do you have for me?"
#     },
#     {
#       "document": 28,
#       "label": "Factual",
#       "text": "Who is your mom?"
#     },
#     {
#       "document": 36,
#       "label": "Factual",
#       "text": "Where is your home town?"
#     },
#     {
#       "document": 55,
#       "label": "Non-factual",
#       "text": "If you could go back in time to change one thing, what would it be?"
#     },
#     {
#       "document": 12,
#       "label": "Factual",
#       "text": "What is your usual breakfast?"
#     },
#     {
#       "document": 38,
#       "label": "Factual",
#       "text": "How much money is in your bank account?"
#     },
#     {
#       "document": 8,
#       "label": "Factual",
#       "text": "Are you a sports fan? If so, what is your favorite team?"
#     },
#     {
#       "document": 33,
#       "label": "Non-factual",
#       "text": "What is consciousness?"
#     },
#     {
#       "document": 27,
#       "label": "Non-factual",
#       "text": "Why do you climb?"
#     },
#     {
#       "document": 43,
#       "label": "Factual",
#       "text": "When do you wake up in the morning?"
#     },
#     {
#       "document": 6,
#       "label": "Factual",
#       "text": "What are or were some of your hobbies?"
#     },
#     {
#       "document": 9,
#       "label": "Factual",
#       "text": "What is an interesting fact about you?"
#     },
#     {
#       "document": 11,
#       "label": "Non-factual",
#       "text": "What makes you feel most alive?"
#     },
#     {
#       "document": 3,
#       "label": "Non-factual",
#       "text": "What do you want others to know or understand about you?"
#     },
#     {
#       "document": 18,
#       "label": "Factual",
#       "text": "Who is your wife?"
#     },
#     {
#       "document": 29,
#       "label": "Non-factual",
#       "text": "Don't you think it would benefit all of us to embrace the irrational a bit more or not to be so risk-averse in a way?"
#     },
#     {
#       "document": 14,
#       "label": "Non-factual",
#       "text": "Would you admit that most humans in pockets of society live within a status quo, that we live within the median, we don't take enough risks?"
#     },
#     {
#       "document": 7,
#       "label": "Non-factual",
#       "text": "If you're feeling down, how do you cheer yourself up?"
#     },
#     {
#       "document": 57,
#       "label": "Factual",
#       "text": "How many languages do you speak?"
#     },
#     {
#       "document": 58,
#       "label": "Factual",
#       "text": "Who was your favorite teacher in school and why?"
#     },
#     {
#       "document": 44,
#       "label": "Factual",
#       "text": "How much does a Tesla cost?"
#     },
#     {
#       "document": 46,
#       "label": "Factual",
#       "text": "How did you learn how to climb?"
#     },
#     {
#       "document": 53,
#       "label": "Non-factual",
#       "text": "What are your dreams?"
#     },
#     {
#       "document": 52,
#       "label": "Factual",
#       "text": "What do you care about most?"
#     },
#     {
#       "document": 51,
#       "label": "Non-factual",
#       "text": "Why did you freesolo El Capitan in Yosemite?"
#     },
#     {
#       "document": 5,
#       "label": "Non-factual",
#       "text": "What are you most grateful for this year?"
#     },
#     {
#       "document": 50,
#       "label": "Non-factual",
#       "text": "Why do you love climbing?"
#     },
#     {
#       "document": 22,
#       "label": "Factual",
#       "text": "What are your thoughts about fear during climbing?"
#     },
#     {
#       "document": 49,
#       "label": "Factual",
#       "text": "At what age did you start studying?"
#     }
#   ]
# }

# %%
question_type = openai.Classification.create(
    search_model="babbage", 
    model="davinci",
    examples= examples,
    query="Tell me your understanding of life",
    labels = ["Factual","Non-factual"],    
    max_examples=len(examples)
)
question_type["label"]
# Out:
# 'Non-factual'

# %%
question_type = openai.Classification.create(
    search_model="babbage", 
    model="davinci",
    examples= examples,
    query="How much money do you make?",
    labels = ["Factual","Non-factual"],    
    max_examples=len(examples)
)
question_type["label"]
# Out:
# 'Factual'

# %%
question_type = openai.Classification.create(
    search_model="ada", 
    model="davinci",
    examples= examples,
    query="Why do you love climbing?",
    labels = ["Factual","Non-factual"],    
    max_examples=len(examples)
)
question_type["label"]
# Out:
# 'Non-factual'

# %% [markdown]
# ## Question Answering

# %%
# Upload file for Q&A model
# openai.File.create(file=open("questionanswer.jsonl"), 
#                    purpose="answers")
# Out:
# <File file id=file-mcgwAkzglsZSibNyeFuuGjcH at 0x7fcdf112ce90> JSON: {
#   "bytes": 378225,
#   "created_at": 1637812059,
#   "filename": "questionanswer.jsonl",
#   "id": "file-mcgwAkzglsZSibNyeFuuGjcH",
#   "object": "file",
#   "purpose": "answers",
#   "status": "uploaded",
#   "status_details": null
# }

# %%
try:
  qa_answer = openai.Answer.create(
      search_model="babbage", 
      model="davinci", 
      question="Tell me some advice for a new climber", 
      file="file-mcgwAkzglsZSibNyeFuuGjcH",
      examples_context="In 2017, U.S. life expectancy was 78.6 years.", 
      examples=[["What is human life expectancy in the United States?", "78 years."]], 
      max_rerank=200,
      max_tokens=25,
      temperature=0.2,
      stop=["\n", "<|endoftext|>"]
  )
  qa_answer_parse = qa_answer['answers'][0]

  if not qa_answer_parse.endswith("."):
    print("not complete")
    qa_answer_x = qa_answer_parse.split(".")
    print(qa_answer_x)
    print(qa_answer_x[0]+'.')
  else: 
    print("complete")
    print(qa_answer_parse)
except:
  print("This is not within my training data, I don't have the an answer. Sorry.")
# Out:
# complete
# Get a pair of climbing shoes.
